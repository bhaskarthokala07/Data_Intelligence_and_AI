# %%
li=[1,2,3,4,5]
a=sum(li)
print(a)
# Out:
# 15

# %%
li=[12,24,35,40,100]
a=max(li)
b=min(li)
print(f"max {a}");
print(f"max {b}");
# Out:
# max 100
# max 12

# %%
li=[12,24,35,40,100]
e=0
o=0
for i in li:
    if i%2==0:
        e+=1
    else :
        o+=1
print(e)
print(o)
# Out:
# 4
# 1
